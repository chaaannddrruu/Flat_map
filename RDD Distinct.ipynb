# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("distinct")
sc = SparkContext.getOrCreate(conf = conf)

# %%
rdd = sc.textFile("/FileStore/tables/sample.txt")
rdd.collect()
# Out:
# Out[3]: ['1 2 3 4 5', '3 4 5 66 77', '12 43 6 7 8', '12 12 33']

# %%
type(rdd)
# Out:
# Out[4]: pyspark.rdd.RDD

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("hmc").appName("local").getOrCreate()
df = spark.read.text("/FileStore/tables/sample.txt")
df.show()
# Out:
# +-----------+
# |      value|
# +-----------+
# |  1 2 3 4 5|
# |3 4 5 66 77|
# |12 43 6 7 8|
# |   12 12 33|
# +-----------+

# %%
type(df)
# Out:
# Out[8]: pyspark.sql.dataframe.DataFrame

# %%
x = "Chandra"
for i in x:
    print(i,"-", x.count(i))
# Out:
# C - 1
# h - 1
# a - 2
# n - 1
# d - 1
# r - 1
# a - 2

# %%
dict = {}
for i in x:
    if i in dict.keys():
        dict[i]+= 1
    else:
        dict[i]=1
print(dict)
# Out:
# {'C': 1, 'h': 1, 'a': 2, 'n': 1, 'd': 1, 'r': 1}

# %%
y = "bbbbbb"
list1 = []
for i in y:
    if i not in list1:
        list1.append(i)
    else: 
        pass
print(list1)
# Out:
# ['b']
